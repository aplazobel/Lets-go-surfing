# %%
import json
import requests

# %%
x = "4bf49534c534477aa8a80201202707"
q = "41.113531,-8.665331"

url = f"http://api.worldweatheronline.com/premium/v1/marine.ashx?key={x}&format=json&q={q}"
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
def coordReformat(lat, long):

# %%
data = res.json()

# %%
data
# Out:
# {'data': {'request': [{'type': 'LatLon', 'query': 'Lat 41.11 and Lon -8.67'}],
#   'weather': [{'date': '2020-07-27',
#     'astronomy': [{'sunrise': '06:25 AM',
#       'sunset': '08:56 PM',
#       'moonrise': '02:03 PM',
#       'moonset': '12:39 AM',
#       'moon_phase': 'First Quarter',
#       'moon_illumination': '48'}],
#     'maxtempC': '26',
#     'maxtempF': '78',
#     'mintempC': '18',
#     'mintempF': '64',
#     'hourly': [{'time': '0',
#       'tempC': '19',
#       'tempF': '66',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '353',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '65',
#       'visibility': '10',
#       'visibilityMiles': '6',
# ...

# %%
for i in data["data"]["weather"]:
    json_formatted_str = json.dumps(i, indent=2)
    #print(json_formatted_str)
    print(i["date"])
# Out:
# 2020-07-27
# 2020-07-28
# 2020-07-29
# 2020-07-30
# 2020-07-31
# 2020-08-01
# 2020-08-02

# %%
data
# Out:
# {'data': {'request': [{'type': 'LatLon', 'query': 'Lat 45.00 and Lon -2.00'}],
#   'weather': [{'date': '2020-07-27',
#     'astronomy': [{'sunrise': '06:47 AM',
#       'sunset': '09:39 PM',
#       'moonrise': '02:38 PM',
#       'moonset': '01:08 AM',
#       'moon_phase': 'First Quarter',
#       'moon_illumination': '48'}],
#     'maxtempC': '22',
#     'maxtempF': '71',
#     'mintempC': '19',
#     'mintempF': '67',
#     'hourly': [{'time': '0',
#       'tempC': '20',
#       'tempF': '68',
#       'windspeedMiles': '10',
#       'windspeedKmph': '16',
#       'winddirDegree': '67',
#       'winddir16Point': 'ENE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '78',
#       'visibility': '10',
#       'visibilityMiles': '6',
# ...
